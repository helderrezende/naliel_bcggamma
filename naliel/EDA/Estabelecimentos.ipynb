# %%
import pandas as pd

# %% [markdown]
# ### Hospital Especializado

# %%
estabelecimentos = pd.read_csv('../data/Estabelecimentos- Hospital Especializado.csv', sep=';', skiprows=3, encoding='latin1')

# %%
estabelecimentos
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       Período:2014-2018
# ...
