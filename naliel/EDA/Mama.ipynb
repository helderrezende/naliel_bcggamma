# %%
import pandas as pd

# %% [markdown]
# # Mama

# %%
data = pd.read_csv('../data/Mama Radioterapia SIA-SUS.csv', error_bad_lines=False, encoding='latin1')

data = data.drop('Unnamed: 0', 1)
# Out:
# b'Skipping line 100354: expected 74 fields, saw 87\n'

# %%
data.head()
# Out:
#    AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  AP_PRIPAL  \
# 0  201401        EP     120000    2001586  1214200029130  201401  304010090
# 1  201401        EP     120000    2001586  1213200185890  201401  304010090
# 2  201402        EP     120000    2001586  1214200045400  201402  304010090
# 3  201402        EP     120000    2001586  1214200045322  201402  304010090
# 4  201402        EP     120000    2001586  1214200045212  201402  304010090
#
#    AP_VL_AP  AP_UFMUN  AP_TPUPS  ...  AR_CIDTR3 AR_NUMC1   AR_INIAR1  \
# 0       990    120040         5  ...        NaN     50.0  20140106.0
# 1      1950    120040         5  ...       C771     50.0  20131216.0
# 2       690    120040         5  ...        NaN     50.0  20140217.0
# 3       390    120040         5  ...        NaN     10.0  20140211.0
# 4      2490    120040         5  ...       C773     50.0  20140204.0
#
#     AR_INIAR2   AR_INIAR3   AR_FIMAR1   AR_FIMAR2   AR_FIMAR3  AR_NUMC2  \
# ...

# %%
data.describe()
# Out:
#               AP_MVM      AP_GESTAO     AP_CODUNI    AP_AUTORIZ  \
# count  313991.000000  313991.000000  3.139910e+05  3.139910e+05
# mean   201610.810851  338336.154683  2.076599e+06  3.386367e+12
# std       141.857585   73526.042579  1.208658e+06  7.345724e+11
# min    201401.000000  110000.000000  4.340000e+02  1.114200e+12
# 25%    201504.000000  292740.000000  2.078775e+06  2.918203e+12
# 50%    201608.000000  350000.000000  2.237253e+06  3.514214e+12
# 75%    201710.000000  410000.000000  2.558246e+06  4.113201e+12
# max    201903.000000  530000.000000  9.255400e+06  5.318202e+12
#
#               AP_CMP     AP_PRIPAL       AP_VL_AP       AP_UFMUN  \
# count  313991.000000  3.139910e+05  313991.000000  313991.000000
# mean   201610.065900  3.040103e+08    1523.160931  338973.060836
# std       141.584044  5.112415e+01    1132.380589   73532.027716
# min    201401.000000  3.040101e+08       0.000000  110004.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313991 entries, 0 to 313990
# Data columns (total 73 columns):
# AP_MVM        313991 non-null int64
# AP_CONDIC     313991 non-null object
# AP_GESTAO     313991 non-null int64
# AP_CODUNI     313991 non-null int64
# AP_AUTORIZ    313991 non-null int64
# AP_CMP        313991 non-null int64
# AP_PRIPAL     313991 non-null int64
# AP_VL_AP      313991 non-null int64
# AP_UFMUN      313991 non-null int64
# AP_TPUPS      313991 non-null int64
# AP_TIPPRE     313991 non-null int64
# AP_MN_IND     313991 non-null object
# AP_CNPJCPF    313991 non-null int64
# AP_CNPJMNT    207430 non-null float64
# AP_CNSPCN     313991 non-null object
# AP_COIDADE    313991 non-null int64
# AP_NUIDADE    313991 non-null int64
# AP_SEXO       313991 non-null object
# AP_RACACOR    313991 non-null int64
# AP_MUNPCN     313991 non-null int64
# AP_UFNACIO    313989 non-null float64
# AP_CEPPCN     313991 non-null int64
# AP_UFDIF      313991 non-null int64
# ...
