# %%
import pandas as pd
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from datalayer import read_csv_sia, read_sia_model
import utils


pd.set_option('display.max_columns', 500)
# %matplotlib inline

# %% [markdown]
# Reading data...

# %%
data_model = read_sia_model('../data/Prostata Radioterapia SIA-SUS.csv', 'radioterapia')
data_model = data_model[['AP_CODUNI', 'AP_CODUNI_LATITUDE' , 'AP_CODUNI_LONGITUDE', 'AP_UFMUN']]
# Out:
# b'Skipping line 40771: expected 74 fields, saw 113\n'
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: DtypeWarning: Columns (38,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/external_data.py:39: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skiprows=3, skipfooter=2, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:59: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')

# %% [markdown]
# ### Municipio para ter certeza do municipio do hospital

# %%
municipio = pd.read_csv('../data/municipios.csv', sep=',')
municipio.columns = [x.upper() for x in municipio.columns]

municipio['CODIGO_IBGE'] = municipio['CODIGO_IBGE'].astype(str)
# numero verificador removed
municipio['CODIGO_IBGE'] = municipio['CODIGO_IBGE'].str[:-1]
municipio['CODIGO_IBGE'] = pd.to_numeric(municipio['CODIGO_IBGE'])

municipio = municipio.rename(columns={'CODIGO_IBGE': 'AP_UFMUN'})

municipio = municipio[['AP_UFMUN', 'NOME']].copy()

# %%
data_model = data_model.merge(municipio, on='AP_UFMUN', how='left')
data_model = data_model.drop_duplicates(subset='AP_CODUNI')
data_model = data_model.sort_values('AP_CODUNI')

# %%
cnes_df = pd.read_csv('../data/espelho cnes nome fantasia.csv', sep=';', encoding='latin1')
cnes_df = cnes_df.rename(columns={'cnes': 'AP_CODUNI'})

# %%
data_model = data_model.merge(cnes_df, on='AP_CODUNI', how='left')

# %%
data_model
# Out:
#      AP_CODUNI  AP_CODUNI_LATITUDE  AP_CODUNI_LONGITUDE  AP_UFMUN  \
# 0          434           -8.066860           -34.890000    261160
# 1          582           -8.050060           -34.878970    261160
# 2         1023           -8.054000           -34.881000    261160
# 3         2283          -10.918970           -37.059330    280030
# 4         3786          -12.991150           -38.485480    292740
# 5         3808          -12.938070           -38.422000    292740
# 6         3832          -12.973710           -38.502610    292740
# 7         4251          -13.002310           -38.524300    292740
# 8         8753          -23.662210           -46.532920    354780
# 9         9369          -23.191550           -45.890450    354990
# 10        9717          -20.450950           -54.614660    500270
# 11        9776          -20.460650           -54.621670    500270
# 12       10456          -15.802840           -47.889670    530010
# 13       10510          -15.724770           -47.886680    530010
# 14       11738          -20.298630           -40.317560    320530
# 15       13633          -25.328810           -49.081130    410400
# 16       14109          -24.026990           -52.401010    410430
# 17       15598          -25.422040           -49.290200    410690
# 18       15644          -25.454170           -49.239470    410690
# 16            Campo Mourão                HOSPITAL SANTA CASA DE MISERICORDIA
# 17                Curitiba                   CLINICA PARANAENSE DE TUMORES SC
# 18                Curitiba                           HOSPITAL ERASTO GAERTNER
# 19             Pato Branco                            POLICLINICA PATO BRANCO
# 20           Florianópolis                      IMPERIAL HOSPITAL DE CARIDADE
# 21           Florianópolis                                            CEPONSC
# 22           Volta Redonda                                              HINJA
# 23          Belo Horizonte                  COMPLEXO HOSPITALAR SAO FRANCISCO
# 24          Belo Horizonte                             HOSPITAL FELICIO ROCHO
# 25          Belo Horizonte                       SANTA CASA DE BELO HORIZONTE
# 26              Rio Branco                                          FUNDHACRE
# 27               Arapiraca                                              CHAMA
# 28                  Maceió        HOSPITAL UNIVERSITARIO PROF ALBERTO ANTUNES
# 29                  Maceió               SANTA CASA DE MISERICORDIA DE MACEIO
# ..                     ...                                                ...
# 142              Fortaleza        CRIO CENTRO REGIONAL INTEGRADO DE ONCOLOGIA
# 143              Fortaleza                           HOSPITAL HAROLDO JUACABA
# 144               Teresina                                HOSPITAL SAO MARCOS
# 145               Cascavel                                              CEONC
# 146               Cascavel            HOSPITAL DO CANCER DE CASCAVEL UOPECCAN
# 147               Botucatu                  HOSPITAL DAS CLINICAS DE BOTUCATU
# 148               Criciúma                                  HOSPITAL SAO JOSE
# 149               Varginha                                HOSPITAL BOM PASTOR
# 150             Piracicaba                           SANTA CASA DE PIRACICABA
# 151   Vitória da Conquista                                      ONCOMED RADIO
# 152                 Passos               SANTA CASA DE MISERICORDIA DE PASSOS
# 153                Jundiaí                         HCSVP HOSPITAL SAO VICENTE
# 154                  Bauru                            HOSPITAL ESTADUAL BAURU
# 155  São José do Rio Preto  SANTA CASA DE MISERICORDIA DE SAO JOSE DO RIO ...
# 156               Salvador                             HOSPITAL SANTO ANTONIO
# 157                Aracaju               HOSPITAL GOVERNADOR JOAO ALVES FILHO
# 158                 Sobral               SANTA CASA DE MISERICORDIA DE SOBRAL
# 159                Taubaté               HOSPITAL REGIONAL DO VALE DO PARAIBA
# 160           Pouso Alegre    ONCOMINAS ONCOLOGIA E RADIOTERAPIA POUSO ALEGRE
# 161                 Manaus                                   CLINICA SENSUMED
# 162                Niterói                   CRI CLINICA DE RADIOTERAPIA INGA
# 163          Volta Redonda                       RADICLIN CENTRO DE ONCOLOGIA
# 164                Mossoró                                  HOSPITAL DA LMECC
# 165               Ourinhos                             SANTA CASA DE OURINHOS
# 166               Santarém  HOSPITAL REGIONAL DO BAIXO AMAZONAS DO PA DR W...
# 167              São Paulo         INSTITUTO DO CANCER DO ESTADO DE SAO PAULO
# 168                 Cacoal                    HOSPITAL REGIONAL DE CACOAL HRC
# 169                  Jales                             HOSPITAL DE AMOR JALES
# 170           Ponta Grossa           INSTITUTO SUL PARANAENSE DE RADIOTERAPIA
# 171                 Palmas                                 IRRADIAR DE PALMAS
#
# [172 rows x 6 columns]
