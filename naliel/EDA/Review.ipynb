# %%
import pandas as pd
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from datalayer import read_csv_sia, read_sia_model
import utils


pd.set_option('display.max_columns', 500)
# %matplotlib inline

# %% [markdown]
# Reading data...

# %%
data_model = read_sia_model('../data/Prostata Radioterapia SIA-SUS.csv', 'radioterapia')
data_model = data_model[['AP_CODUNI', 'AP_CODUNI_LATITUDE' , 'AP_CODUNI_LONGITUDE', 'AP_UFMUN']]
# Out:
# b'Skipping line 40771: expected 74 fields, saw 113\n'
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: DtypeWarning: Columns (38,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/external_data.py:39: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skiprows=3, skipfooter=2, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:59: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')

# %% [markdown]
# ### Municipio para ter certeza do municipio do hospital

# %%
municipio = pd.read_csv('../data/municipios.csv', sep=',')
municipio.columns = [x.upper() for x in municipio.columns]

municipio['CODIGO_IBGE'] = municipio['CODIGO_IBGE'].astype(str)
# numero verificador removed
municipio['CODIGO_IBGE'] = municipio['CODIGO_IBGE'].str[:-1]
municipio['CODIGO_IBGE'] = pd.to_numeric(municipio['CODIGO_IBGE'])

municipio = municipio.rename(columns={'CODIGO_IBGE': 'AP_UFMUN'})

municipio = municipio[['AP_UFMUN', 'NOME']].copy()

# %%
data_model = data_model.merge(municipio, on='AP_UFMUN', how='left')
data_model = data_model.drop_duplicates(subset='AP_CODUNI')
data_model = data_model.sort_values('AP_CODUNI')

# %%
data_model
# Out:
#        AP_CODUNI  AP_CODUNI_LATITUDE  AP_CODUNI_LONGITUDE  AP_UFMUN  \
# 30593        434           -8.066860           -34.890000    261160
# 30603        582           -8.050060           -34.878970    261160
# 30585       1023           -8.054000           -34.881000    261160
# 58140       2283          -10.918970           -37.059330    280030
# 1130        3786          -12.991150           -38.485480    292740
# 1178        3808          -12.938070           -38.422000    292740
# 1139        3832          -12.973710           -38.502610    292740
# 1154        4251          -13.002310           -38.524300    292740
# 58771       8753          -23.662210           -46.532920    354780
# 58874       9369          -23.191550           -45.890450    354990
# 25720       9717          -20.450950           -54.614660    500270
# 25721       9776          -20.460650           -54.621670    500270
# 11527      10456          -15.802840           -47.889670    530010
# 11521      10510          -15.724770           -47.886680    530010
# 11641      11738          -20.298630           -40.317560    320530
# 34519      13633          -25.328810           -49.081130    410400
# 34747      14109          -24.026990           -52.401010    410430
# 34516      15598          -25.422040           -49.290200    410690
# 34541      15644          -25.454170           -49.239470    410690
# 34515      17868          -26.229350           -52.675520    411850
# 55607      19402          -27.602830           -48.545360    420540
# 55586      19445          -27.577660           -48.511610    420540
# 44277      25186          -22.510950           -44.081800    330630
# 14066      26840          -19.902980           -43.933520    310620
# 14012      26859          -19.922990           -43.957540    310620
# 14045      27014          -19.920590           -43.928870    310620
# 0        2001586           -9.977400           -67.805850    120040
# 70       2005417           -9.723140           -36.680580    270030
# 74       2006197           -9.666250           -35.735090    270430
# 71       2007037           -9.665840           -35.741330    270430
# ...          ...                 ...                  ...       ...
# 7253     2723190           -3.713310           -38.572560    230440
# 7251     2723220           -3.747250           -38.553060    230440
# 33239    2726998           -5.091550           -42.805210    221100
# 34526    2737434          -24.961700           -53.458250    410480
# 34514    2740338          -24.968790           -53.502560    410480
# 58811    2748223          -22.897370           -48.491290    350750
# 55585    2758164          -28.677280           -49.368010    420460
# 14011    2761092          -21.547670           -45.448290    317070
# 58801    2772310          -22.737590           -47.643690    353870
# 1126     2772566          -14.872210           -40.844960    293330
# 14002    2775999          -20.711720           -46.609150    314790
# 58843    2786435          -23.183490           -46.889680    352590
# 58738    2790602          -22.349470           -49.032490    350600
# 58739    2798298          -20.811770           -49.394630    354980
# 3731     2802104          -12.929920           -38.507390    292740
# 58160    2816210          -10.928000           -37.080950    280030
# 7383     3021114           -3.686640           -40.350790    231290
# 58859    3126838          -23.029290           -45.566370    355410
# 22808    3145425          -22.232170           -45.940030    315250
# 891      3400557           -3.085710           -59.886060    130260
# 41039    3477371          -22.903300           -43.126520    330330
# 40999    3502651          -22.523000           -44.100160    330630
# 47935    3675580           -5.186700           -37.346020    240800
# 71366    4049020          -22.981980           -49.862620    353470
# 28193    5585422           -2.451670           -54.715460    150680
# 58900    6123740          -23.546980           -46.656590    355030
# 48581    6599877          -11.426840           -61.463470    110004
# 70217    7066376          -20.269000           -50.546000    352480
# 38630    7205686          -25.090230           -50.163650    411990
# 79116    9255400          -10.214371           -48.354426    172100
#
#                         NOME
# 30593                 Recife
# 30603                 Recife
# 30585                 Recife
# 58140                Aracaju
# 1130                Salvador
# 1178                Salvador
# 1139                Salvador
# 1154                Salvador
# 58771            Santo André
# 58874    São José dos Campos
# 25720           Campo Grande
# 25721           Campo Grande
# 11527               Brasília
# 11521               Brasília
# 11641                Vitória
# 34519  Campina Grande do Sul
# 34747           Campo Mourão
# 34516               Curitiba
# 34541               Curitiba
# 34515            Pato Branco
# 55607          Florianópolis
# 55586          Florianópolis
# 44277          Volta Redonda
# 14066         Belo Horizonte
# 14012         Belo Horizonte
# 14045         Belo Horizonte
# 0                 Rio Branco
# 70                 Arapiraca
# 74                    Maceió
# 71                    Maceió
# ...                      ...
# 7253               Fortaleza
# 7251               Fortaleza
# 33239               Teresina
# 34526               Cascavel
# 34514               Cascavel
# 58811               Botucatu
# 55585               Criciúma
# 14011               Varginha
# 58801             Piracicaba
# 1126    Vitória da Conquista
# 14002                 Passos
# 58843                Jundiaí
# 58738                  Bauru
# 58739  São José do Rio Preto
# 3731                Salvador
# 58160                Aracaju
# 7383                  Sobral
# 58859                Taubaté
# 22808           Pouso Alegre
# 891                   Manaus
# 41039                Niterói
# 40999          Volta Redonda
# 47935                Mossoró
# 71366               Ourinhos
# 28193               Santarém
# 58900              São Paulo
# 48581                 Cacoal
# 70217                  Jales
# 38630           Ponta Grossa
# 79116                 Palmas
#
# [172 rows x 5 columns]
