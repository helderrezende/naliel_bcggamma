# %%
import pandas as pd
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from model import predict_sia
import shap

pd.set_option('display.max_columns', 500)
# %matplotlib inline

# %% [markdown]
# ### LINFOMA

# %% [markdown]
# #### Radioterapia

# %%
model, X, X_with_cep = predict_sia('../data/Linfomas Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (42,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# training model...
# Accuracy: 62.41%

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
model, X, X_with_cep = predict_sia('../data/Linfomas Quimioterapia SIA-SUS.csv', method='quimioterapia')

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### MAMA

# %% [markdown]
# #### Radioterapia

# %%
model, X, X_with_cep = predict_sia('../data/Mama Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# b'Skipping line 100354: expected 74 fields, saw 87\n'
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (33,38,40,42,44,45,49,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Accuracy: 63.30%

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
model, X, X_with_cep = predict_sia('../data/Mama Radioterapia SIA-SUS.csv', method='radioterapia')

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### PROSTATA

# %% [markdown]
# #### Radioterapia

# %%
model, X, X_with_cep = predict_sia('../data/Prostata Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# b'Skipping line 40771: expected 74 fields, saw 113\n'
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (38,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Accuracy: 73.21%

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
# %time model, X, X_with_cep = predict_sia('../data/Prostata Quimioterapia SIA-SUS.csv', method='quimioterapia')

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### Pulmão

# %% [markdown]
# #### Radioterapia

# %%
model, X, X_with_cep = predict_sia('../data/Pulmão Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Accuracy: 81.22%

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
# %time model, X, X_with_cep = predict_sia('../data/Pulmão Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (21,38,39,41,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# training model...
# Accuracy: 90.18%
# CPU times: user 9min 6s, sys: 8.07 s, total: 9min 14s
# Wall time: 8min 2s

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### COLO

# %%
model, X, X_with_cep = predict_sia('../data/Colon e reto Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Accuracy: 64.51%

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")
