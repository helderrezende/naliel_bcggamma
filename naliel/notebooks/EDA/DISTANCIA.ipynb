# %%
import pandas as pd
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from datalayer import read_sia_model
import utils


pd.set_option('display.max_columns', 500)
# %matplotlib inline

# %% [markdown]
# ### Reading data

# %%
data_model = read_sia_model('../data/Linfomas Radioterapia SIA-SUS.csv', 'radioterapia')
# Out:
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: DtypeWarning: Columns (42,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/helderrezende/Documents/naliel_bcggamma/datalayer.py:16: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/datalayer.py:55: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')

# %%
data_model.sort_values('DISTANCE_HOSPITAL', ascending=False)
# Out:
#        AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  \
# 6158   201603        EP     350000    2090236  3516214557339  201603
# 5728   201502        EP     350000    2090236  3515203866603  201502
# 12276  201508        EP     110000    2515377  1115200541994  201508
# 12280  201509        EP     110000    2515377  1115200541994  201509
# 190    201803        EP     130000    2012677  1318200108544  201802
# 192    201804        EP     130000    2012677  1318200108544  201803
# 5146   201810        EP     430000    2261057  4318205396934  201810
# 5138   201809        EP     430000    2261057  4318205396934  201809
# 15456  201805        EP     350000    2083086  3518211140070  201805
# 15408  201804        EP     350000    2083086  3518211140070  201804
# 13646  201503        EP     350000    2079798  3515215569570  201503
# 5890   201507        EP     350000    2090236  3515230300824  201507
# 5842   201506        EP     350000    2090236  3515230271784  201506
# ...

# %%
data_col = data_model[['AP_CEPPCN_LATITUDE', 'AP_CEPPCN_LONGITUDE',
                            'AP_CODUNI_LATITUDE', 'AP_CODUNI_LONGITUDE', 'DISTANCE_HOSPITAL']]

# %%
data_col
# Out:
#        AP_CEPPCN_LATITUDE  AP_CEPPCN_LONGITUDE  AP_CODUNI_LATITUDE  \
# 0               -8.940801           -72.793130           -9.977400
# 1               -8.940801           -72.793130           -9.977400
# 2               -9.950606           -67.797489           -9.977400
# 3              -11.029454           -68.740728           -9.977400
# 4               -9.950606           -67.797489           -9.977400
# 5              -11.029454           -68.740728           -9.977400
# 6              -10.005000           -67.791511           -9.977400
# 7              -10.651541           -68.499271           -9.977400
# 8              -10.005000           -67.791511           -9.977400
# 9               -9.976483           -67.808094           -9.977400
# 10             -10.124999           -36.176150           -9.665840
# 11              -9.508860           -35.815222           -9.666250
# 12              -9.583984           -35.771367           -9.665840
# ...
