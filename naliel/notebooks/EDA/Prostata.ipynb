# %%
import pandas as pd

# %% [markdown]
# ### Lendo os dados

# %%
data = pd.read_csv('../data/Prostata Quimioterapia SIA-SUS.csv', error_bad_lines=False, encoding='latin1')

# %%
data = data.drop('Unnamed: 0', 1)

# %% [markdown]
# #### Colunas

# %%
data.columns
# Out:
# Index(['AP_MVM', 'AP_CONDIC', 'AP_GESTAO', 'AP_CODUNI', 'AP_AUTORIZ', 'AP_CMP',
#        'AP_PRIPAL', 'AP_VL_AP', 'AP_UFMUN', 'AP_TPUPS', 'AP_TIPPRE',
#        'AP_MN_IND', 'AP_CNPJCPF', 'AP_CNPJMNT', 'AP_CNSPCN', 'AP_COIDADE',
#        'AP_NUIDADE', 'AP_SEXO', 'AP_RACACOR', 'AP_MUNPCN', 'AP_UFNACIO',
#        'AP_CEPPCN', 'AP_UFDIF', 'AP_MNDIF', 'AP_DTINIC', 'AP_DTFIM',
#        'AP_TPATEN', 'AP_TPAPAC', 'AP_MOTSAI', 'AP_OBITO', 'AP_ENCERR',
#        'AP_PERMAN', 'AP_ALTA', 'AP_TRANSF', 'AP_DTOCOR', 'AP_CODEMI',
#        'AP_CATEND', 'AP_APACANT', 'AP_UNISOL', 'AP_DTSOLIC', 'AP_DTAUT',
#        'AP_CIDCAS', 'AP_CIDPRI', 'AP_CIDSEC', 'AP_ETNIA', 'AQ_CID10',
#        'AQ_LINFIN', 'AQ_ESTADI', 'AQ_GRAHIS', 'AQ_DTIDEN', 'AQ_TRANTE',
#        'AQ_CIDINI1', 'AQ_DTINI1', 'AQ_CIDINI2', 'AQ_DTINI2', 'AQ_CIDINI3',
#        'AQ_DTINI3', 'AQ_CONTTR', 'AQ_DTINTR', 'AQ_ESQU_P1', 'AQ_TOTMPL',
#        'AQ_TOTMAU', 'AQ_ESQU_P2'],
#       dtype='object')

# %%
data.describe()
# Out:
#              AP_MVM     AP_GESTAO     AP_CODUNI    AP_AUTORIZ        AP_CMP  \
# count  3.167299e+06  3.167299e+06  3.167299e+06  3.167299e+06  3.167299e+06
# mean   2.016128e+05  3.359013e+05  2.150126e+06  3.364291e+12  2.016120e+05
# std    1.420092e+02  8.035444e+04  1.054725e+06  8.031609e+11  1.417991e+02
# min    2.014010e+05  1.100000e+05  3.960000e+02  1.114200e+12  2.014010e+05
# 25%    2.015040e+05  2.910800e+05  2.081644e+06  2.916201e+12  2.015040e+05
# 50%    2.016070e+05  3.304550e+05  2.255936e+06  3.317204e+12  2.016070e+05
# 75%    2.017110e+05  3.550300e+05  2.564211e+06  3.518241e+12  2.017100e+05
# max    2.019030e+05  5.300000e+05  8.003629e+06  5.318202e+12  2.018120e+05
#
#           AP_PRIPAL      AP_VL_AP      AP_UFMUN      AP_TPUPS     AP_TIPPRE  \
# count  3.167299e+06  3.167299e+06  3.167299e+06  3.167299e+06  3.167299e+06
# mean   3.040208e+08  3.364524e+02  3.366976e+05  6.864570e+00  1.857738e+01
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3167299 entries, 0 to 3167298
# Data columns (total 63 columns):
# AP_MVM        int64
# AP_CONDIC     object
# AP_GESTAO     int64
# AP_CODUNI     int64
# AP_AUTORIZ    int64
# AP_CMP        int64
# AP_PRIPAL     int64
# AP_VL_AP      float64
# AP_UFMUN      int64
# AP_TPUPS      int64
# AP_TIPPRE     int64
# AP_MN_IND     object
# AP_CNPJCPF    int64
# AP_CNPJMNT    float64
# AP_CNSPCN     object
# AP_COIDADE    int64
# AP_NUIDADE    int64
# AP_SEXO       object
# AP_RACACOR    int64
# AP_MUNPCN     int64
# AP_UFNACIO    float64
# AP_CEPPCN     object
# AP_UFDIF      int64
# AP_MNDIF      float64
# AP_DTINIC     float64
# AP_DTFIM      int64
# AP_TPATEN     int64
# AP_TPAPAC     int64
# AP_MOTSAI     object
# AP_OBITO      object
# AP_ENCERR     float64
# AP_PERMAN     object
# AP_ALTA       object
# AP_TRANSF     float64
# AP_DTOCOR     object
# AP_CODEMI     object
# AP_CATEND     object
# AP_APACANT    object
# ...

# %%
data.head()
# Out:
#    AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  AP_PRIPAL  \
# 0  201401        EP     120000    2001586  1213200186033  201401  304020079
# 1  201401        EP     120000    2001586  1214200017569  201401  304020079
# 2  201401        EP     120000    2001586  1214200017130  201401  304020079
# 3  201401        EP     120000    2001586  1213200179433  201401  304020079
# 4  201401        EP     120000    2001586  1214200016975  201401  304020079
#
#    AP_VL_AP  AP_UFMUN  AP_TPUPS  ...  AQ_CIDINI2 AQ_DTINI2  AQ_CIDINI3  \
# 0     301.5    120040         5  ...         NaN       NaN         NaN
# 1     301.5    120040         5  ...         NaN       NaN         NaN
# 2     751.0    120040         5  ...         NaN       NaN         NaN
# 3     301.5    120040         5  ...         NaN       NaN         NaN
# 4     751.0    120040         5  ...         NaN       NaN         NaN
#
#    AQ_DTINI3 AQ_CONTTR   AQ_DTINTR  AQ_ESQU_P1 AQ_TOTMPL  AQ_TOTMAU  \
# ...

# %%
data[data['AP_CEPPCN'] == 4533013]
# Out:
#          AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  \
# 2429913  201406        EP     350000    6123740  3514219767531  201405
# 2440109  201406        EP     350000    6123740  3514219767531  201406
# 2443879  201407        EP     350000    6123740  3514219767531  201407
# 2479565  201410        EP     350000    6123740  3514242036932  201410
# 2502867  201411        EP     350000    6123740  3514242036932  201411
# 2509624  201412        EP     350000    6123740  3514242036932  201412
# 2528674  201501        EP     350000    6123740  3515202021914  201501
# 2534811  201502        EP     350000    6123740  3515202021914  201502
# 2544643  201503        EP     350000    6123740  3515202021914  201503
# 2569757  201505        EP     350000    6123740  3515218291233  201504
# 2580795  201505        EP     350000    6123740  3515218291233  201505
# 2587721  201506        EP     350000    6123740  3515218291233  201506
# ...

# %%
type(data['AP_CEPPCN'].iloc[0])
# Out:
# int
