# %%
import pandas as pd
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from datalayer import read_csv_sia, read_sia_model
import utils


pd.set_option('display.max_columns', 500)
# %matplotlib inline
# %load_ext line_profiler

# %% [markdown]
# ## Radioterapia
#
#
# Dates columns
#
#
# - AP_DTINIC - Data de inicio validade
# - AP_DTFIM - Data de fim validade
# - AP_DTOCOR - Data de ocorrencia
# - AP_DTSOLIC - Data de solicatacao
# - AP_DTAUT - Data de autorizacao
# - AP_DTIDEN - Data da identificacao patologica
# - AR_DTINTR - Data de inicio do tratamento solicitado
# - AR_INIAR1 - Data de inicio 1
# - AR_FIMAR1 - Data de fim 1

# %% [markdown]
# ### Reading data...

# %%
import numpy as np
from datetime import timedelta

# %%
# %time teste = read_sia_model('../data/Pulmão Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/magics/execution.py:1310: DtypeWarning: Columns (21,38,39,41,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code, glob, local_ns)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')
# CPU times: user 56.8 s, sys: 6.91 s, total: 1min 3s
# Wall time: 34.2 s

# %%
teste.groupby('AR_ESTADI').count()
# Out:
#            AP_MVM  AP_CONDIC  AP_GESTAO  AP_CODUNI  AP_AUTORIZ  AP_CMP  \
# AR_ESTADI
# 0            2801       2801       2801       2801        2801    2801
# 1            2734       2734       2734       2734        2734    2734
# 2            4674       4674       4674       4674        4674    4674
# 3           22454      22454      22454      22454       22454   22454
# 4           56698      56698      56698      56698       56698   56698
#
#            AP_PRIPAL  AP_VL_AP  AP_UFMUN  AP_TPUPS  AP_TIPPRE  AP_MN_IND  \
# AR_ESTADI
# 0               2801      2801      2801      2801       2801       2801
# 1               2734      2734      2734      2734       2734       2734
# 2               4674      4674      4674      4674       4674       4674
# 3              22454     22454     22454     22454      22454      22454
# 4              56698     56698     56698     56698      56698      56698
#
#            AP_CNPJCPF  AP_CNPJMNT  AP_CNSPCN  AP_COIDADE  AP_NUIDADE  AP_SEXO  \
# AR_ESTADI
# 0                2801        2099       2801        2801        2801     2801
# 1                2734        2191       2734        2734        2734     2734
# 2                4674        3338       4674        4674        4674     4674
# 3               22454       15778      22454       22454       22454    22454
# 4               56697       43052      56698       56698       56698    56698
#
#            AP_RACACOR  AP_MUNPCN  AP_UFNACIO  AP_CEPPCN  AP_UFDIF  AP_MNDIF  \
# AR_ESTADI
# 0                2801       2801        2801       2801      2801      2801
# 1                2734       2734        2734       2734      2734      2734
# 2                4674       4674        4674       4674      4674      4674
# 3               22454      22454       22454      22454     22454     22454
# 4               56698      56698       56698      56698     56698     56698
#
#            AP_DTINIC  AP_DTFIM  AP_TPAPAC  AP_MOTSAI  AP_OBITO  AP_ENCERR  \
# AR_ESTADI
# 0               2801      2801       2801       2801      2801       2801
# 1               2734      2734       2734       2734      2734       2734
# 2               4674      4674       4674       4674      4674       4674
# 3              22454     22454      22454      22454     22454      22454
# 4              56698     56698      56698      56698     56698      56698
#
#            AP_PERMAN  AP_ALTA  AP_TRANSF  AP_DTOCOR  AP_CODEMI  AP_CATEND  \
# AR_ESTADI
# 0               2801     2801       2801         95       2801       2801
# 1               2734     2734       2734        169       2734       2734
# 2               4674     4674       4674        434       4674       4674
# 3              22454    22454      22454       1522      22454      22454
# 4              56698    56698      56698       2695      56698      56698
#
#            AP_APACANT  AP_UNISOL  AP_DTSOLIC  AP_DTAUT  AP_CIDCAS  AP_CIDSEC  \
# AR_ESTADI
# 0                2555       2771        2484      2307       2801       2801
# 1                2586       2732        2574      2437       2734       2734
# 2                4359       4669        4448      3452       4674       4674
# 3               20830      22402       21457     16450      22454      22454
# 4               51274      56524       54363     42559      56698      56698
#
#            AQ_CID10  AQ_LINFIN  AQ_GRAHIS  AR_DTIDEN  AQ_TRANTE  AQ_CIDINI1  \
# AR_ESTADI
# 0               838       2801       2800       2801       2801         277
# 1              1543       2734       2732       2734       2734         375
# 2              1229       4674       4669       4674       4674        1104
# 3              6765      22454      22426      22454      22454        4004
# 4             21452      56698      56638      56698      56698        9508
#
#            AQ_DTINI1  AQ_DTINI2  AQ_CONTTR  AQ_DTINTR  AQ_ESQU_P1  AQ_TOTMPL  \
# AR_ESTADI
# 0                347        127       2801       2801        2801       2801
# 1                433        132       2734       2734        2734       2734
# 2               1350        503       4674       4674        4674       4674
# 3               5385       2551      22454      22453       22454      22454
# 4              13504       6700      56698      56697       56698      56698
#
#            AQ_TOTMAU  AQ_ESQU_P2  EWM_MEAN_DELAY  AP_CEPPCN_REGIAO  \
# AR_ESTADI
# 0               2801        2241            2787              2801
# 1               2734        2455            2726              2734
# 2               4674        4119            4668              4674
# 3              22454       19770           22423             22454
# 4              56698       50377           56579             56698
#
#            AP_CEPPCN_SUBREGIAO  AP_CEPPCN_SETOR  AP_CEPPCN_SUBSETOR  \
# AR_ESTADI
# 0                         2801             2801                2801
# 1                         2734             2734                2734
# 2                         4674             4674                4674
# 3                        22454            22454               22454
# 4                        56698            56698               56698
#
#            AP_CEPPCN_DIVISOR_SUBSETOR  AP_CEPPCN_SUFIXO_DISTRIBUICAO  \
# AR_ESTADI
# 0                                2801                           2801
# 1                                2734                           2734
# 2                                4674                           4674
# 3                               22454                          22454
# 4                               56698                          56698
#
#            AP_MUNPCN_NOME  AP_MUNPCN_LATITUDE  AP_MUNPCN_LONGITUDE  \
# AR_ESTADI
# 0                    2791                2791                 2791
# 1                    2733                2733                 2733
# 2                    4663                4663                 4663
# 3                   22422               22422                22422
# 4                   56503               56503                56503
#
#            AP_MUNPCN_CAPITAL  AP_MUNPCN_CODIGO_UF  AP_UFMUN_NOME  \
# AR_ESTADI
# 0                       2791                 2791           2800
# 1                       2733                 2733           2734
# 2                       4663                 4663           4673
# 3                      22422                22422          22452
# 4                      56503                56503          56680
#
#            AP_UFMUN_LATITUDE  AP_UFMUN_LONGITUDE  AP_UFMUN_CAPITAL  \
# AR_ESTADI
# 0                       2800                2800              2800
# 1                       2734                2734              2734
# 2                       4673                4673              4673
# 3                      22452               22452             22452
# 4                      56680               56680             56680
#
#            AP_UFMUN_CODIGO_UF  AP_MUNPCN_GINI  AP_MUNPCN_RDPC  \
# AR_ESTADI
# 0                        2800            2791            2791
# 1                        2734            2733            2733
# 2                        4673            4663            4663
# 3                       22452           22414           22414
# 4                       56680           56500           56500
#
#            AP_MUNPCN_T_AGUA  AP_MUNPCN_T_BANAGUA  AP_MUNPCN_AGUA_ESGOTO  \
# AR_ESTADI
# 0                      2791                 2791                   2791
# 1                      2733                 2733                   2733
# 2                      4663                 4663                   4663
# 3                     22414                22414                  22414
# 4                     56500                56500                  56500
#
#            AP_MUNPCN_T_LIXO  AP_MUNPCN_I_ESCOLARIDADE  AP_MUNPCN_I_FREQ_PROP  \
# AR_ESTADI
# 0                      2791                      2791                   2791
# 1                      2733                      2733                   2733
# 2                      4663                      4663                   4663
# 3                     22414                     22414                  22414
# 4                     56500                     56500                  56500
#
#            AP_MUNPCN_IDHM  AP_MUNPCN_IDHM_E  AP_MUNPCN_IDHM_L  \
# AR_ESTADI
# 0                    2791              2791              2791
# 1                    2733              2733              2733
# 2                    4663              4663              4663
# 3                   22414             22414             22414
# 4                   56500             56500             56500
#
#            AP_MUNPCN_IDHM_R  AP_MUNPCN_T_SLUZ  AP_CEPPCN_TIPO_SEM_ACENTO  \
# AR_ESTADI
# 0                      2791              2791                       1965
# 1                      2733              2733                       1953
# 2                      4663              4663                       3091
# 3                     22414             22414                      13995
# 4                     56500             56500                      36291
#
#            AP_CEPPCN_NOME_LOGRADOURO_SEM_ACENTO  \
# AR_ESTADI
# 0                                          1965
# 1                                          1952
# 2                                          3082
# 3                                         13917
# 4                                         36197
#
#            AP_CEPPCN_LOGRADOURO_SEM_ACENTO  AP_CEPPCN_LATITUDE  \
# AR_ESTADI
# 0                                     1965                2797
# 1                                     1953                2732
# 2                                     3091                4643
# 3                                    13995               22358
# 4                                    36291               56424
#
#            AP_CEPPCN_LONGITUDE  AP_CODUNI_LATITUDE  AP_CODUNI_LONGITUDE  \
# AR_ESTADI
# 0                         2797                2801                 2801
# 1                         2732                2734                 2734
# 2                         4643                4674                 4674
# 3                        22358               22454                22454
# 4                        56424               56698                56698
#
#            AP_CODUNI_NOTA  AP_CODUNI_QT  AR_DTIDEN_YEAR_MONTH  AR_DTIDEN_YEAR  \
# AR_ESTADI
# 0                    2724          2792                  2801            2801
# 1                    2708          2734                  2734            2734
# 2                    4541          4674                  4674            4674
# 3                   21654         22425                 22454           22454
# 4                   54335         56654                 56698           56698
#
#            AP_MUNPCN_MUNIC-BR  AP_MUNPCN_FREQÜÊNCIA  AP_MUNPCN_POPULAÇÃO  \
# AR_ESTADI
# 0                           0                  2782                 2782
# 1                           0                  2730                 2730
# 2                           0                  4637                 4637
# 3                           0                 22319                22319
# 4                           0                 56206                56206
#
#            AP_MUNPCN_1.1_%R.LÍQUIDA_TOTAL  \
# AR_ESTADI
# 0                                    2782
# 1                                    2730
# 2                                    4637
# 3                                   22319
# 4                                   56206
#
#            AP_MUNPCN_1.2_%TRANSF._INTERGOV._LÍQUIDAS  \
# AR_ESTADI
# 0                                               2782
# 1                                               2730
# 2                                               4637
# 3                                              22319
# 4                                              56206
#
#            AP_MUNPCN_1.3_%TRANSF._PARA_A_SAÚDE_(SUS)  \
# AR_ESTADI
# 0                                               2782
# 1                                               2730
# 2                                               4637
# 3                                              22319
# 4                                              56206
#
#            AP_MUNPCN_1.4_%TRANSF._UNIÃO_P/_SAÚDE  \
# AR_ESTADI
# 0                                           2782
# 1                                           2730
# 2                                           4637
# 3                                          22319
# 4                                          56205
#
#            AP_MUNPCN_1.5_%TRANSF._DA_UNIÃO_P/_(SUS)  \
# AR_ESTADI
# 0                                              2782
# 1                                              2730
# 2                                              4637
# 3                                             22319
# 4                                             56206
#
#            AP_MUNPCN_1.6_%R.IMP._TRANSF.CONST.LEGAIS  \
# AR_ESTADI
# 0                                               2782
# 1                                               2730
# 2                                               4637
# 3                                              22319
# 4                                              56206
#
#            AP_MUNPCN_2.1_D.TOTAL_SAÚDE/HAB  AP_MUNPCN_2.2_%D.PESSOAL/D.TOTAL  \
# AR_ESTADI
# 0                                     2782                              2782
# 1                                     2730                              2730
# 2                                     4637                              4637
# 3                                    22319                             22319
# 4                                    56206                             56206
#
#            AP_MUNPCN_2.3_%D.COM_MEDICAMENTOS  \
# AR_ESTADI
# 0                                       2782
# 1                                       2730
# 2                                       4637
# 3                                      22319
# 4                                      56206
#
#            AP_MUNPCN_2.4_%D.SERV.TERC/D.TOTAL  \
# AR_ESTADI
# 0                                        2782
# 1                                        2730
# 2                                        4637
# 3                                       22319
# 4                                       56206
#
#            AP_MUNPCN_2.5_%D.INVEST/D.TOTAL  \
# AR_ESTADI
# 0                                     2782
# 1                                     2730
# 2                                     4637
# 3                                    22319
# 4                                    56206
#
#            AP_MUNPCN_2.10\tSUBFUNÇÕES_ADMINISTRATIVAS  \
# AR_ESTADI
# 0                                                1219
# 1                                                1157
# 2                                                2184
# 3                                               10474
# 4                                               24860
#
#            AP_MUNPCN_2.20\tSUBFUNÇÕES_VINCULADAS  \
# AR_ESTADI
# 0                                           1219
# 1                                           1157
# 2                                           2184
# 3                                          10474
# 4                                          24860
#
#            AP_MUNPCN_2.21\tATENÇÃO_BÁSICA  \
# AR_ESTADI
# 0                                    1219
# 1                                    1157
# 2                                    2184
# 3                                   10474
# 4                                   24860
#
#            AP_MUNPCN_2.22_ASSIS._HOSP._E_AMBULAT.  \
# AR_ESTADI
# 0                                            1219
# 1                                            1157
# 2                                            2184
# 3                                           10474
# 4                                           24860
#
#            AP_MUNPCN_2.23_SUP._PROFILÁTICO_TERAP.  \
# AR_ESTADI
# 0                                            1219
# 1                                            1157
# 2                                            2184
# 3                                           10474
# 4                                           24860
#
#            AP_MUNPCN_2.24_VIGILÂNCIA_SANITÁRIA  \
# AR_ESTADI
# 0                                         1219
# 1                                         1157
# 2                                         2184
# 3                                        10474
# 4                                        24860
#
#            AP_MUNPCN_2.25_VIGILÂNCIA_EPIDEMIOLÓGICA  \
# AR_ESTADI
# 0                                              1219
# 1                                              1157
# 2                                              2184
# 3                                             10474
# 4                                             24860
#
#            AP_MUNPCN_2.26_ALIMENTAÇÃO_E_NUTRIÇÃO  \
# AR_ESTADI
# 0                                           1219
# 1                                           1157
# 2                                           2184
# 3                                          10474
# 4                                          24860
#
#            AP_MUNPCN_2.30_INFORMAÇÕES_COMPLEMENTARES  \
# AR_ESTADI
# 0                                               1219
# 1                                               1157
# 2                                               2184
# 3                                              10474
# 4                                              24860
#
#            AP_MUNPCN_3.1_%TRANSF.SUS/D.TOTAL  \
# AR_ESTADI
# 0                                       2782
# 1                                       2730
# 2                                       4637
# 3                                      22319
# 4                                      56206
#
#            AP_MUNPCN_3.2_%R.PRÓPRIOS_EM_SAÚDE-EC_29  \
# AR_ESTADI
# 0                                              2782
# 1                                              2730
# 2                                              4637
# 3                                             22319
# 4                                             56206
#
#            AP_MUNPCN_R.IMPOSTOS_E_TRANSF.CONST  AP_MUNPCN_R.TRANSF.SUS  \
# AR_ESTADI
# 0                                         2782                    2782
# 1                                         2730                    2730
# 2                                         4637                    4637
# 3                                        22319                   22319
# 4                                        56206                   56206
#
#            AP_MUNPCN_R.TRANSF.SUS/HAB  AP_MUNPCN_D.PESSOAL  \
# AR_ESTADI
# 0                                2782                 2782
# 1                                2730                 2730
# 2                                4637                 4637
# 3                               22319                22319
# 4                               56206                56206
#
#            AP_MUNPCN_D.R.PRÓPRIOS  AP_MUNPCN_D.R.PRÓPRIOS_EM_SAÚDE/HAB  \
# AR_ESTADI
# 0                            2782                                 2782
# 1                            2730                                 2730
# 2                            4637                                 4637
# 3                           22319                                22319
# 4                           56206                                56206
#
#            AP_MUNPCN_D.TOTAL_SAÚDE  CLINICAS_AMB_ESPECIALIZADO  \
# AR_ESTADI
# 0                             2782                        2782
# 1                             2730                        2730
# 2                             4637                        4636
# 3                            22319                       22318
# 4                            56206                       56203
#
#            HOSPITAL_ESPECIALIZADO  HOSPITAL_GERAL  UN_BASICA_SAUDE  \
# AR_ESTADI
# 0                            2782            2782             2782
# 1                            2730            2730             2730
# 2                            4636            4636             4636
# 3                           22318           22318            22318
# 4                           56203           56203            56203
#
#            UN_DIAG_TERAPIA  LEITOS_INTERNACAO  MAMOGRAFOS  RAIO_X  TOMAGRAFOS  \
# AR_ESTADI
# 0                     2782               2782        2782    2782        2782
# 1                     2730               2730        2730    2730        2730
# 2                     4636               4636        4636    4636        4636
# 3                    22318              22318       22318   22318       22318
# 4                    56203              56203       56203   56203       56203
#
#            RESSONANCIA_MAGNETICA  MEDICOS  ENFERMEIROS  DISTANCE_HOSPITAL
# AR_ESTADI
# 0                           2782     2782         2782               2797
# 1                           2730     2730         2730               2732
# 2                           4636     4636         4636               4643
# 3                          22318    22318        22318              22358
# 4                          56203    56203        56203              56424

# %%
review = pd.read_csv('{0}/data/reviews.csv'.format('..'), sep=';')
review['Nota'] = review['Nota'].apply(pd.to_numeric, errors='coerce')
review.columns = [col.upper() for col in review.columns]

# %%
data = read_sia_model('../data/Linfomas Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: DtypeWarning: Columns (38,39,41,42,44,45,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')

# %%
set(data['AP_CODUNI'].unique()) - set(review['AP_CODUNI'].unique())
# Out:
# {2006448,
#  2071371,
#  2088576,
#  2269988,
#  2295067,
#  2296616,
#  2409151,
#  2563681,
#  2649527,
#  2691868,
#  2716801,
#  4028155,
#  4044916,
#  5869412,
#  6048692,
#  6602533,
#  6876617,
#  7185081,
#  7871902}

# %%
len(data['AP_CNSPCN'].unique())
# Out:
# 93344

# %%
data['AP_CNSPCN'].iloc[110]
# Out:
# '\x82{{~{}\x84\x81\x7f\x82}\x81}~|'

# %%
data[data['AP_CNSPCN'] == '\x83\x84\x83{{}\x84{}~\x81\x80\x84\x84\x80']
# Out:
#         AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ     AP_CMP  \
# 97  2016-03-01        EP     120000    2001586  1216200068589 2016-03-01
# 110 2016-04-01        EP     120000    2001586  1216200068589 2016-04-01
# 118 2016-05-01        EP     120000    2001586  1216200068589 2016-05-01
#
#      AP_PRIPAL  AP_VL_AP  AP_UFMUN  AP_TPUPS  AP_TIPPRE AP_MN_IND  \
# 97   304010090      2278    120040         5          0         I
# 110  304010090      2070    120040         5          0         I
# 118  304010090       750    120040         5          0         I
#
#          AP_CNPJCPF  AP_CNPJMNT        AP_CNSPCN  AP_COIDADE  AP_NUIDADE  \
# 97   63602940000170         NaN  {{}{}~           4          66
# 110  63602940000170         NaN  {{}{}~           4          66
# 118  63602940000170         NaN  {{}{}~           4          66
#
#     AP_SEXO  AP_RACACOR  AP_MUNPCN  AP_UFNACIO  AP_CEPPCN  AP_UFDIF  AP_MNDIF  \
# 97        M           3     120040        10.0   69900001         0         1
# 110       M           3     120045        10.0   69925000         0         1
# 118       M           3     120045        10.0   69925000         0         1
#
#      AP_DTINIC   AP_DTFIM  AP_TPAPAC  AP_MOTSAI  AP_OBITO  AP_ENCERR  \
# 97  2016-03-10 2016-05-31          1         21         0          0
# 110 2016-03-10 2016-05-31          2         21         0          0
# 118 2016-03-10 2016-05-31          2         15         0          0
#
#      AP_PERMAN  AP_ALTA  AP_TRANSF  AP_DTOCOR   AP_CODEMI  AP_CATEND  \
# 97           1        0          0        NaT  E120000001          1
# 110          1        0          0        NaT  E120000001          1
# 118          0        1          0 2016-05-31  E120000001          1
#
#     AP_APACANT  AP_UNISOL AP_DTSOLIC   AP_DTAUT AP_CIDCAS AP_CIDSEC AR_CID10  \
# 97           0  2001586.0 2016-03-10 2016-03-10         0      0000      NaN
# 110          0  2001586.0 2016-03-10 2016-03-10         0      0000      NaN
# 118          0  2001586.0 2016-03-10 2016-03-10         0      0000      NaN
#
#     AR_LINFIN  AR_ESTADI AR_GRAHIS  AR_DTIDEN AR_TRANTE AR_CIDINI1  AR_DTINI1  \
# 97          3          4        99 2015-09-22       NaN        NaN        NaN
# 110         3          4        99 2015-09-22       NaN        NaN        NaN
# 118         3          4        99 2015-09-22       NaN        NaN        NaN
#
#     AR_CONTTR  AR_DTINTR  AR_FINALI AR_CIDTR1 AR_CIDTR2  AR_NUMC1  AR_INIAR1  \
# 97          N 2016-03-10          1       C61       NaN     144.0 2016-03-10
# 110         N 2016-03-10          1       C61       NaN     144.0 2016-03-10
# 118         N 2016-03-10          1       C61       NaN     144.0 2016-03-10
#
#      AR_INIAR2  AR_FIMAR1  AR_FIMAR2  AR_NUMC2  AR_NUMC3 AP_DTSOLIC-AUT  \
# 97         NaN 2016-05-31        NaN       NaN       NaN         0 days
# 110        NaN 2016-05-31        NaN       NaN       NaN         0 days
# 118        NaN 2016-05-31        NaN       NaN       NaN         0 days
#
#      AP_OCOR_POS_MVM AP_OCOR_VAL_DT  AP_OCOR_VAL
# 97                 1            NaT            0
# 110                1            NaT            0
# 118                1     2016-05-31            1

# %%
len(data)
# Out:
# 19920

# %%
data[data['AP_CNSPCN'] == '\x83\x84\x83{{\x7f{||\x83\x81~\x83{\x84']
# Out:
#       AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ     AP_CMP  \
# 0 2014-01-01        EP     120000    2001586  1214200029152 2014-01-01
# 4 2014-02-01        EP     120000    2001586  1214200029152 2014-02-01
#
#    AP_PRIPAL  AP_VL_AP  AP_UFMUN  AP_TPUPS  AP_TIPPRE AP_MN_IND  \
# 0  304010090      1170    120040         5         40         I
# 4  304010090      2190    120040         5         40         I
#
#        AP_CNPJCPF  AP_CNPJMNT        AP_CNSPCN  AP_COIDADE  AP_NUIDADE  \
# 0  63602940000170         NaN  {{{||~{           4          68
# 4  63602940000170         NaN  {{{||~{           4          68
#
#   AP_SEXO  AP_RACACOR  AP_MUNPCN  AP_UFNACIO  AP_CEPPCN  AP_UFDIF  AP_MNDIF  \
# 0       M           3     120040        10.0   69900970         0         1
# 4       M           3     120040        10.0   69900970         0         1
#
#    AP_DTINIC   AP_DTFIM  AP_TPAPAC  AP_MOTSAI  AP_OBITO  AP_ENCERR  AP_PERMAN  \
# 0 2014-01-21 2014-03-31          1         21         0          0          1
# 4 2014-01-21 2014-03-31          2         15         0          0          0
#
#    AP_ALTA  AP_TRANSF  AP_DTOCOR   AP_CODEMI  AP_CATEND AP_APACANT  AP_UNISOL  \
# 0        0          0        NaT  E120000001          1          0  2001586.0
# 4        1          0 2014-02-28  E120000001          1          0  2001586.0
#
#   AP_DTSOLIC   AP_DTAUT AP_CIDCAS AP_CIDSEC AR_CID10 AR_LINFIN  AR_ESTADI  \
# 0 2014-01-21 2014-01-21         0      0000      NaN         3          4
# 4 2014-01-21 2014-01-21         0      0000      NaN         3          4
#
#   AR_GRAHIS  AR_DTIDEN AR_TRANTE AR_CIDINI1  AR_DTINI1 AR_CONTTR  AR_DTINTR  \
# 0        99 2013-12-12       NaN        NaN        NaN         N 2014-01-21
# 4        99 2013-12-12       NaN        NaN        NaN         N 2014-01-21
#
#    AR_FINALI AR_CIDTR1 AR_CIDTR2  AR_NUMC1  AR_INIAR1  AR_INIAR2  AR_FIMAR1  \
# 0          1       C61       NaN     144.0 2014-01-21        NaN 2014-03-31
# 4          1       C61       NaN     144.0 2014-01-21        NaN 2014-03-31
#
#    AR_FIMAR2  AR_NUMC2  AR_NUMC3 AP_DTSOLIC-AUT  AP_OCOR_POS_MVM  \
# 0        NaN       NaN       NaN         0 days                1
# 4        NaN       NaN       NaN         0 days                1
#
#   AP_OCOR_VAL_DT  AP_OCOR_VAL
# 0            NaT            0
# 4     2014-02-28            1

# %%
data[data['AP_CNSPCN'] == '\x83\x84\x83{{}~\x81}\x82\x83\x80\x80\x80\x83']
# Out:
#        AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ     AP_CMP  \
# 5  2014-02-01        EP     120000    2001586  1214200045311 2014-02-01
# 10 2014-03-01        EP     120000    2001586  1214200045311 2014-03-01
#
#     AP_PRIPAL  AP_VL_AP  AP_UFMUN  AP_TPUPS  AP_TIPPRE AP_MN_IND  \
# 5   304010090      1890    120040         5         40         I
# 10  304010090      2550    120040         5         40         I
#
#         AP_CNPJCPF  AP_CNPJMNT        AP_CNSPCN  AP_COIDADE  AP_NUIDADE  \
# 5   63602940000170         NaN  {{}~}           4          78
# 10  63602940000170         NaN  {{}~}           4          78
#
#    AP_SEXO  AP_RACACOR  AP_MUNPCN  AP_UFNACIO  AP_CEPPCN  AP_UFDIF  AP_MNDIF  \
# 5        M           3     120040        10.0   69900970         0         1
# 10       M           3     120040        10.0   69900970         0         1
#
#     AP_DTINIC   AP_DTFIM  AP_TPAPAC  AP_MOTSAI  AP_OBITO  AP_ENCERR  \
# 5  2014-02-10 2014-04-30          1         21         0          0
# 10 2014-02-10 2014-04-30          2         15         0          0
#
#     AP_PERMAN  AP_ALTA  AP_TRANSF  AP_DTOCOR   AP_CODEMI  AP_CATEND  \
# 5           1        0          0        NaT  E120000001          1
# 10          0        1          0 2014-03-31  E120000001          1
#
#    AP_APACANT  AP_UNISOL AP_DTSOLIC   AP_DTAUT AP_CIDCAS AP_CIDSEC AR_CID10  \
# 5           0  2001586.0 2014-02-10 2014-02-10         0      0000      NaN
# 10          0  2001586.0 2014-02-10 2014-02-10         0      0000      NaN
#
#    AR_LINFIN  AR_ESTADI AR_GRAHIS  AR_DTIDEN AR_TRANTE AR_CIDINI1  AR_DTINI1  \
# 5          3          4        99 2014-01-03       NaN        NaN        NaN
# 10         3          4        99 2014-01-03       NaN        NaN        NaN
#
#    AR_CONTTR  AR_DTINTR  AR_FINALI AR_CIDTR1 AR_CIDTR2  AR_NUMC1  AR_INIAR1  \
# 5          N 2014-02-10          1       C61       NaN     144.0 2014-02-10
# 10         N 2014-02-10          1       C61       NaN     144.0 2014-02-10
#
#     AR_INIAR2  AR_FIMAR1  AR_FIMAR2  AR_NUMC2  AR_NUMC3 AP_DTSOLIC-AUT  \
# 5         NaN 2014-04-30        NaN       NaN       NaN         0 days
# 10        NaN 2014-04-30        NaN       NaN       NaN         0 days
#
#     AP_OCOR_POS_MVM AP_OCOR_VAL_DT  AP_OCOR_VAL
# 5                 1            NaT            0
# 10                1     2014-03-31            1

# %%
data[data['AP_CNSPCN']

# %%
data.iloc[10]
# Out:
# AP_MVM             2014-03-01 00:00:00
# AP_CONDIC                           EP
# AP_GESTAO                       120000
# AP_CODUNI                      2001586
# AP_AUTORIZ               1214200045311
#                           ...
# AR_NUMC3                           NaN
# AP_DTSOLIC-AUT         0 days 00:00:00
# AP_OCOR_POS_MVM                      1
# AP_OCOR_VAL_DT     2014-03-31 00:00:00
# AP_OCOR_VAL                          1
# Name: 10, Length: 66, dtype: object

# %%
data.sort_values('AP_OCOR_VAL', ascending=False)[['AP_OCOR_POS_MVM']]
# Out:
#         AP_OCOR_POS_MVM
# 71227                 1
# 186374                1
# 80547                 1
# 80544                 1
# 80543                 1
# ...                 ...
# 94595                 1
# 94596                 1
# 94597                 1
# 94598                 1
# 245162                1
#
# [245163 rows x 1 columns]

# %%
data_model = read_sia_model('../data/Prostata Radioterapia SIA-SUS.csv', 'radioterapia')
# Out:
# b'Skipping line 40771: expected 74 fields, saw 113\n'
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3325: DtypeWarning: Columns (38,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/external_data.py:39: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   skiprows=3, skipfooter=2, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:59: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')

# %%
data_model[['AP_CODUNI', 'AP_CODUNI_LATITUDE' , 'AP_CODUNI_LONGITUDE', 'AP_UFMUN', 'AP_MUNPCN_NOME']]
# Out:
#        AP_CODUNI  AP_CODUNI_LATITUDE  AP_CODUNI_LONGITUDE  AP_UFMUN  \
# 0        2001586           -9.977400           -67.805850    120040
# 1        2001586           -9.977400           -67.805850    120040
# 2        2001586           -9.977400           -67.805850    120040
# 3        2001586           -9.977400           -67.805850    120040
# 4        2001586           -9.977400           -67.805850    120040
# 5        2001586           -9.977400           -67.805850    120040
# 6        2001586           -9.977400           -67.805850    120040
# 7        2001586           -9.977400           -67.805850    120040
# 8        2001586           -9.977400           -67.805850    120040
# 9        2001586           -9.977400           -67.805850    120040
# 10       2001586           -9.977400           -67.805850    120040
# 11       2001586           -9.977400           -67.805850    120040
# 12       2001586           -9.977400           -67.805850    120040
# 13       2001586           -9.977400           -67.805850    120040
# 14       2001586           -9.977400           -67.805850    120040
# 15       2001586           -9.977400           -67.805850    120040
# 16       2001586           -9.977400           -67.805850    120040
# 17       2001586           -9.977400           -67.805850    120040
# 18       2001586           -9.977400           -67.805850    120040
# 19       2001586           -9.977400           -67.805850    120040
# 20       2001586           -9.977400           -67.805850    120040
# 21       2001586           -9.977400           -67.805850    120040
# 22       2001586           -9.977400           -67.805850    120040
# 23       2001586           -9.977400           -67.805850    120040
# 24       2001586           -9.977400           -67.805850    120040
# 25       2001586           -9.977400           -67.805850    120040
# 26       2001586           -9.977400           -67.805850    120040
# 27       2001586           -9.977400           -67.805850    120040
# 28       2001586           -9.977400           -67.805850    120040
# 29       2001586           -9.977400           -67.805850    120040
# ...          ...                 ...                  ...       ...
# 79110    2600536           -7.193300           -48.209370    170210
# 79111    2600536           -7.193300           -48.209370    170210
# 79112    2600536           -7.193300           -48.209370    170210
# 79113    2600536           -7.193300           -48.209370    170210
# 79114    2600536           -7.193300           -48.209370    170210
# 79115    2600536           -7.193300           -48.209370    170210
# 79116    9255400          -10.214371           -48.354426    172100
# 79117    9255400          -10.214371           -48.354426    172100
# 79118    9255400          -10.214371           -48.354426    172100
# 79119    9255400          -10.214371           -48.354426    172100
# 79120    9255400          -10.214371           -48.354426    172100
# 79121    9255400          -10.214371           -48.354426    172100
# 79122    9255400          -10.214371           -48.354426    172100
# 79123    9255400          -10.214371           -48.354426    172100
# 79124    9255400          -10.214371           -48.354426    172100
# 79125    9255400          -10.214371           -48.354426    172100
# 79126    9255400          -10.214371           -48.354426    172100
# 79127    9255400          -10.214371           -48.354426    172100
# 79128    9255400          -10.214371           -48.354426    172100
# 79129    9255400          -10.214371           -48.354426    172100
# 79130    9255400          -10.214371           -48.354426    172100
# 79131    9255400          -10.214371           -48.354426    172100
# 79132    9255400          -10.214371           -48.354426    172100
# 79133    9255400          -10.214371           -48.354426    172100
# 79134    9255400          -10.214371           -48.354426    172100
# 79135    9255400          -10.214371           -48.354426    172100
# 79136    9255400          -10.214371           -48.354426    172100
# 79137    9255400          -10.214371           -48.354426    172100
# 79138    9255400          -10.214371           -48.354426    172100
# 79139    9255400          -10.214371           -48.354426    172100
#
#                    AP_MUNPCN_NOME
# 0                      Rio Branco
# 1                      Rio Branco
# 2                      Rio Branco
# 3                  Epitaciolândia
# 4                      Rio Branco
# 5                       Brasiléia
# 6                      Rio Branco
# 7                  Sena Madureira
# 8                      Rio Branco
# 9                          Xapuri
# 10                     Rio Branco
# 11              Plácido de Castro
# 12                       Capixaba
# 13                 Sena Madureira
# 14                     Rio Branco
# 15                     Rio Branco
# 16                     Rio Branco
# 17                     Rio Branco
# 18                     Rio Branco
# 19                       Capixaba
# 20                     Acrelândia
# 21                     Rio Branco
# 22                     Rio Branco
# 23                     Rio Branco
# 24              Plácido de Castro
# 25                     Rio Branco
# 26                     Rio Branco
# 27                     Rio Branco
# 28                     Rio Branco
# 29                     Rio Branco
# ...                           ...
# 79110                   Araguaína
# 79111                  Araguatins
# 79112                 Luzinópolis
# 79113      Feira Nova do Maranhão
# 79114                   Goianorte
# 79115  São Sebastião do Tocantins
# 79116                    Brasília
# 79117                      Palmas
# 79118                   Araguaína
# 79119                      Palmas
# 79120                      Palmas
# 79121       Miracema do Tocantins
# 79122                      Palmas
# 79123                      Palmas
# 79124              Porto Nacional
# 79125             Nova Rosalândia
# 79126                      Palmas
# 79127    Divinópolis do Tocantins
# 79128                      Palmas
# 79129      São Miguel do Araguaia
# 79130                      Palmas
# 79131                      Palmas
# 79132                     Xambioá
# 79133                      Palmas
# 79134              Augustinópolis
# 79135        Paraíso do Tocantins
# 79136               Figueirópolis
# 79137                      Palmas
# 79138                      Gurupi
# 79139                      Gurupi
#
# [79140 rows x 5 columns]

# %%
data[['AP_CODUNI']]
# Out:
#    AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  AP_PRIPAL  \
# 0  201401        EP     120000    2001586  1214200029119  201401  304010090
# 1  201402        EP     120000    2001586  1214200045201  201402  304010090
# 2  201402        EP     120000    2001586  1214200029119  201402  304010090
# 3  201403        EP     120000    2001586  1214200045201  201403  304010090
# 4  201405        EP     120000    2001586  1214200084944  201405  304010090
#
#    AP_VL_AP  AP_UFMUN  AP_TPUPS  AP_TIPPRE AP_MN_IND      AP_CNPJCPF  \
# 0       614    120040         5         40         I  63602940000170
# 1      2098    120040         5         40         I  63602940000170
# 2       630    120040         5         40         I  63602940000170
# 3      2550    120040         5         40         I  63602940000170
# 4       810    120040         5         40         I  63602940000170
#
#    AP_CNPJMNT        AP_CNSPCN  AP_COIDADE  AP_NUIDADE AP_SEXO  AP_RACACOR  \
# 0         NaN  {{~           4           8       M           3
# 1         NaN  {{}~~{}           4          75       M           3
# 2         NaN  {{~           4           8       M           3
# 3         NaN  {{}~~{}           4          75       M           3
# 4         NaN  }{{{{{|}{{{~           4          13       M           3
#
#    AP_MUNPCN  AP_UFNACIO AP_CEPPCN  AP_UFDIF  AP_DTINIC   AP_DTFIM  AP_TPAPAC  \
# 0     120050          10  69940000         0 2014-01-23 2014-02-28          1
# 1     120040          10  69900970         0 2014-02-12 2014-04-30          1
# 2     120050          10  69940000         0 2014-01-23 2014-02-28          2
# 3     120040          10  69900970         0 2014-02-12 2014-04-30          2
# 4     120020          10  69980000         0 2014-03-18 2014-05-31          2
#
#    AP_MOTSAI  AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  AP_TRANSF  AP_DTOCOR  \
# 0         21         0          0          1        0          0        NaT
# 1         21         0          0          1        0          0        NaT
# 2         15         0          0          0        1          0 2014-02-28
# 3         15         0          0          0        1          0 2014-03-31
# 4         15         0          0          0        1          0 2014-05-31
#
#     AP_CODEMI  AP_CATEND  AP_APACANT  AP_UNISOL AP_DTSOLIC   AP_DTAUT  \
# 0  E120000001          1         0.0  2001586.0 2014-01-23 2014-01-23
# 1  E120000001          1         0.0  2001586.0 2014-02-12 2014-02-12
# 2  E120000001          1         0.0  2001586.0 2014-01-23 2014-01-23
# 3  E120000001          1         0.0  2001586.0 2014-02-12 2014-02-12
# 4  E120000001          1         0.0  2001586.0 2014-03-18 2014-03-18
#
#   AP_CIDCAS                AP_CIDPRI AP_CIDSEC AR_CID10 AR_LINFIN  AR_ESTADI  \
# 0      0000  C81- Linfoma de Hodgkin      0000      NaN         S        2.0
# 1      0000  C81- Linfoma de Hodgkin      0000      NaN         N        2.0
# 2      0000  C81- Linfoma de Hodgkin      0000      NaN         S        2.0
# 3      0000  C81- Linfoma de Hodgkin      0000      NaN         N        2.0
# 4      0000  C81- Linfoma de Hodgkin      0000      NaN         S        3.0
#
#   AR_GRAHIS  AR_DTIDEN AR_TRANTE AR_CIDINI1  AR_DTINI1  AR_DTINI2 AR_CONTTR  \
# 0        99 2013-06-19       NaN        NaN        NaN        NaN         N
# 1        99 2013-10-16       NaN        NaN        NaN        NaN         N
# 2        99 2013-06-19       NaN        NaN        NaN        NaN         N
# 3        99 2013-10-16       NaN        NaN        NaN        NaN         N
# 4        99 2012-05-05       NaN        NaN        NaN        NaN         N
#
#    AR_DTINTR  AR_FINALI AR_CIDTR1 AR_CIDTR2  AR_NUMC1  AR_INIAR1  AR_INIAR2  \
# 0 2013-01-27          2      C811       NaN      34.0 2013-01-27        NaN
# 1 2014-02-12          1       C61       NaN     144.0 2014-02-12        NaN
# 2 2013-01-27          2      C811       NaN      34.0 2013-01-27        NaN
# 3 2014-02-12          1       C61       NaN     144.0 2014-02-12        NaN
# 4 2014-03-18          2      C810       NaN      60.0 2014-03-18        NaN
#
#    AR_FIMAR1  AR_FIMAR2  AR_NUMC2  AR_NUMC3  AP_CEPPCN_REGIAO  \
# 0 2014-02-28        NaN       NaN       NaN                 6
# 1 2014-04-30        NaN       NaN       NaN                 6
# 2 2014-02-28        NaN       NaN       NaN                 6
# 3 2014-03-31        NaN       NaN       NaN                 6
# 4 2014-05-31        NaN       NaN       NaN                 6
#
#    AP_CEPPCN_SUBREGIAO  AP_CEPPCN_SETOR  AP_CEPPCN_SUBSETOR  \
# 0                    9                9                   4
# 1                    9                9                   0
# 2                    9                9                   4
# 3                    9                9                   0
# 4                    9                9                   8
#
#    AP_CEPPCN_DIVISOR_SUBSETOR  AP_CEPPCN_SUFIXO_DISTRIBUICAO   AP_MUNPCN_nome  \
# 0                           4                              0   Sena Madureira
# 1                           0                            970       Rio Branco
# 2                           4                              0   Sena Madureira
# 3                           0                            970       Rio Branco
# 4                           8                              0  Cruzeiro do Sul
#
#    AP_MUNPCN_latitude  AP_MUNPCN_longitude  AP_MUNPCN_capital  \
# 0            -9.06596             -68.6571                0.0
# 1            -9.97499             -67.8243                1.0
# 2            -9.06596             -68.6571                0.0
# 3            -9.97499             -67.8243                1.0
# 4            -7.62762             -72.6756                0.0
#
#    AP_MUNPCN_codigo_uf AP_UFMUN_nome  AP_UFMUN_latitude  AP_UFMUN_longitude  \
# 0                 12.0    Rio Branco           -9.97499            -67.8243
# 1                 12.0    Rio Branco           -9.97499            -67.8243
# 2                 12.0    Rio Branco           -9.97499            -67.8243
# 3                 12.0    Rio Branco           -9.97499            -67.8243
# 4                 12.0    Rio Branco           -9.97499            -67.8243
#
#    AP_UFMUN_capital  AP_UFMUN_codigo_uf AP_CEPPCN_BAIRRO  \
# 0                 1                  12              NaN
# 1                 1                  12           Centro
# 2                 1                  12              NaN
# 3                 1                  12           Centro
# 4                 1                  12              NaN
#
#                AP_CEPPCN_COMPLEMENTO
# 0                                NaN
# 1  Avenida Epaminondas Jácome, 2858
# 2                                NaN
# 3  Avenida Epaminondas Jácome, 2858
# 4                                NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19920 entries, 0 to 19919
# Data columns (total 81 columns):
# AP_MVM                           19920 non-null int64
# AP_CONDIC                        19920 non-null object
# AP_GESTAO                        19920 non-null int64
# AP_CODUNI                        19920 non-null int64
# AP_AUTORIZ                       19920 non-null int64
# AP_CMP                           19920 non-null int64
# AP_PRIPAL                        19920 non-null int64
# AP_VL_AP                         19920 non-null int64
# AP_UFMUN                         19920 non-null int64
# AP_TPUPS                         19920 non-null int64
# AP_TIPPRE                        19920 non-null int64
# AP_MN_IND                        19920 non-null object
# AP_CNPJCPF                       19920 non-null int64
# AP_CNPJMNT                       12755 non-null float64
# AP_CNSPCN                        19920 non-null object
# AP_COIDADE                       19920 non-null int64
# AP_NUIDADE                       19920 non-null int64
# AP_SEXO                          19920 non-null object
# AP_RACACOR                       19920 non-null int64
# AP_MUNPCN                        19920 non-null int64
# AP_UFNACIO                       19920 non-null int64
# AP_CEPPCN                        19920 non-null object
# AP_UFDIF                         19920 non-null int64
# AP_DTINIC                        19920 non-null datetime64[ns]
# AP_DTFIM                         19920 non-null datetime64[ns]
# AP_TPAPAC                        19920 non-null int64
# AP_MOTSAI                        19920 non-null int64
# AP_OBITO                         19920 non-null int64
# AP_ENCERR                        19920 non-null int64
# AP_PERMAN                        19920 non-null int64
# AP_ALTA                          19920 non-null int64
# AP_TRANSF                        19920 non-null int64
# AP_DTOCOR                        8731 non-null datetime64[ns]
# AP_CODEMI                        19920 non-null object
# AP_CATEND                        19920 non-null int64
# AP_APACANT                       17831 non-null float64
# AP_UNISOL                        19818 non-null float64
# AP_DTSOLIC                       18861 non-null datetime64[ns]
# AP_DTAUT                         18441 non-null datetime64[ns]
# AP_CIDCAS                        19920 non-null object
# AP_CIDPRI                        19920 non-null object
# AP_CIDSEC                        19920 non-null object
# AR_CID10                         10676 non-null object
# AR_LINFIN                        19920 non-null object
# AR_ESTADI                        19782 non-null float64
# AR_GRAHIS                        19918 non-null object
# AR_DTIDEN                        19917 non-null datetime64[ns]
# AR_TRANTE                        14260 non-null object
# AR_CIDINI1                       5620 non-null object
# AR_DTINI1                        6792 non-null float64
# AR_DTINI2                        2063 non-null float64
# AR_CONTTR                        19920 non-null object
# AR_DTINTR                        19917 non-null datetime64[ns]
# AR_FINALI                        19920 non-null int64
# AR_CIDTR1                        18523 non-null object
# AR_CIDTR2                        3199 non-null object
# AR_NUMC1                         18860 non-null float64
# AR_INIAR1                        18561 non-null datetime64[ns]
# AR_INIAR2                        3375 non-null float64
# AR_FIMAR1                        18551 non-null datetime64[ns]
# AR_FIMAR2                        3375 non-null float64
# AR_NUMC2                         9822 non-null float64
# AR_NUMC3                         8709 non-null float64
# AP_CEPPCN_REGIAO                 19920 non-null int64
# AP_CEPPCN_SUBREGIAO              19920 non-null int64
# AP_CEPPCN_SETOR                  19920 non-null int64
# AP_CEPPCN_SUBSETOR               19920 non-null int64
# AP_CEPPCN_DIVISOR_SUBSETOR       19920 non-null int64
# AP_CEPPCN_SUFIXO_DISTRIBUICAO    19920 non-null int64
# AP_MUNPCN_nome                   19856 non-null object
# AP_MUNPCN_latitude               19856 non-null float64
# AP_MUNPCN_longitude              19856 non-null float64
# AP_MUNPCN_capital                19856 non-null float64
# AP_MUNPCN_codigo_uf              19856 non-null float64
# AP_UFMUN_nome                    19920 non-null object
# AP_UFMUN_latitude                19920 non-null float64
# AP_UFMUN_longitude               19920 non-null float64
# AP_UFMUN_capital                 19920 non-null int64
# AP_UFMUN_codigo_uf               19920 non-null int64
# AP_CEPPCN_BAIRRO                 9526 non-null object
# AP_CEPPCN_COMPLEMENTO            9536 non-null object
# dtypes: datetime64[ns](9), float64(17), int64(34), object(21)
# memory usage: 12.5+ MB

# %% [markdown]
# ### Analyzing Numerical Variables

# %%
numerical = data._get_numeric_data().columns
data[numerical].hist(bins=15, figsize=(30, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a247d9cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2492b748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24777978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24064320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a25117780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23778ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d4abc88>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc0d5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc0d438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bc27a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d312048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a22f965f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24049ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23e02198>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a22e9c748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d48bcf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a252612e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2522c898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d1fee48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c75a438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d77c9e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1cf7bf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d3ff588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d5c3b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eca90f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1ecd56a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1b6fcc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e96240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a1d68e7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bd9dda0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1bdab390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a240b6940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x106d43ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2484a4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24822a90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a230a5080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1eceb630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d5f4be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a249271d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24913780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cefdd30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1daa2320>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a239bb8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a12e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a24e90470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1cb88a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1c706fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a254915c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2480db70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1a24ee0160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2446f710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a23a0dcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1e2b62b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2537c860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a2542be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d6b1400>]],
#       dtype=object)

# %% [markdown]
# ## Quimioterapia
#
# Dates columns
#
#
# - AP_DTINIC - Data de inicio validade
# - AP_DTFIM - Data de fim validade
# - AP_DTSOLIC - Data de solicatacao
# - AP_DTAUT - Data de autorizacao
# - AQ_DTIDEN - Data da identificacao patologica
# - AQ_DTINTR - Data de inicio do tratamento solicitado

# %%
data = read_csv_sia('../data/Linfomas Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3248: DtypeWarning: Columns (38,39,41,42,44,45,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
data.head()
# Out:
#    AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  AP_PRIPAL  \
# 0  201401        EP     120000    2001586  1213200185967  201401  304060011
# 1  201401        EP     120000    2001586  1213200175561  201401  304060011
# 2  201401        EP     120000    2001586  1213200175528  201401  304060011
# 3  201401        EP     120000    2001586  1213200177266  201401  304060011
# 4  201401        EP     120000    2001586  1213200186275  201401  304070017
#
#    AP_VL_AP  AP_UFMUN  AP_TPUPS  AP_TIPPRE AP_MN_IND    AP_CNPJCPF  \
# 0   1258.64    120040         5         40         I  6.360294e+13
# 1   1258.64    120040         5         40         I  6.360294e+13
# 2   1258.64    120040         5         40         I  6.360294e+13
# 3   1258.64    120040         5         40         I  6.360294e+13
# 4   1700.00    120040         5         40         I  6.360294e+13
#
#    AP_CNPJMNT        AP_CNSPCN  AP_COIDADE  AP_NUIDADE AP_SEXO  AP_RACACOR  \
# 0         NaN  {}{{}{{           4          20       M           3
# 1         NaN  {{|{||           4          46       M           3
# 2         NaN  {{{{|}{|}           4          20       M           3
# 3         NaN  {{{{{}~}           4          61       M           3
# 4         NaN  {{{{{           4          18       F           3
#
#    AP_MUNPCN  AP_UFNACIO AP_CEPPCN  AP_UFDIF  AP_MNDIF  AP_DTINIC   AP_DTFIM  \
# 0     120040          10  69900970         0         1 2013-11-05 2014-01-31
# 1     120040          10  69900970         0         1 2013-11-05 2014-01-31
# 2     120040          10  69900970         0         1 2013-11-05 2014-01-31
# 3     120001          10  69945000         0         1 2013-11-05 2014-01-31
# 4     120040          10  69900970         0         1 2013-11-28 2014-01-31
#
#    AP_TPAPAC  AP_MOTSAI  AP_OBITO  AP_ENCERR  AP_PERMAN  AP_ALTA  AP_TRANSF  \
# 0          2         21         0          0          1        0          0
# 1          2         21         0          0          1        0          0
# 2          2         21         0          0          1        0          0
# 3          2         21         0          0          1        0          0
# 4          2         21         0          0          1        0          0
#
#     AP_CODEMI  AP_CATEND     AP_APACANT AP_UNISOL AP_DTSOLIC   AP_DTAUT  \
# 0  E120000001          1  0000000000000   2001586 2013-11-05 2013-11-05
# 1  E120000001          1  0000000000000         0 2013-11-05 2013-11-05
# 2  E120000001          1  0000000000000         0 2013-11-05 2013-11-05
# 3  E120000001          1  0000000000000         0 2013-11-05 2013-11-05
# 4  E120000001          1  0000000000000   2001586 2013-11-28 2013-11-28
#
#   AP_CIDCAS                AP_CIDPRI AP_CIDSEC AQ_CID10 AQ_LINFIN  AQ_ESTADI  \
# 0      0000  C81- Linfoma de Hodgkin      0000      NaN         3        3.0
# 1      0000  C81- Linfoma de Hodgkin      0000      NaN         3        3.0
# 2      0000  C81- Linfoma de Hodgkin      0000      NaN         3        3.0
# 3      0000  C81- Linfoma de Hodgkin      0000      NaN         3        3.0
# 4      0000  C81- Linfoma de Hodgkin      0000      NaN         3        2.0
#
#   AQ_GRAHIS  AQ_DTIDEN AQ_TRANTE AQ_CIDINI1  AQ_DTINI1  AQ_DTINI2 AQ_CONTTR  \
# 0        99 2013-05-19         0        NaN        NaN        NaN         S
# 1        99 2005-06-02         0        NaN        NaN        NaN         S
# 2        99 2013-05-19         0        NaN        NaN        NaN         S
# 3        99 2013-09-19         0        NaN        NaN        NaN         N
# 4        99 2013-10-31         0        NaN        NaN        NaN         N
#
#    AQ_DTINTR AQ_ESQU_P1 AQ_TOTMPL  AQ_TOTMAU  AQ_ESQU_P2  AP_CEPPCN_REGIAO  \
# 0 2013-08-19       ABVD         6          3         NaN                 6
# 1 2013-08-01       ABVD         6          3         NaN                 6
# 2 2013-08-19       ABVD         6          3         NaN                 6
# 3 2013-08-09      VIMBL         6          3  AS+DAVARBA                 6
# 4 2013-11-28       ABVD         6          0         NaN                 6
#
#    AP_CEPPCN_SUBREGIAO  AP_CEPPCN_SETOR  AP_CEPPCN_SUBSETOR  \
# 0                    9                9                   0
# 1                    9                9                   0
# 2                    9                9                   0
# 3                    9                9                   4
# 4                    9                9                   0
#
#    AP_CEPPCN_DIVISOR_SUBSETOR  AP_CEPPCN_SUFIXO_DISTRIBUICAO AP_MUNPCN_nome  \
# 0                           0                            970     Rio Branco
# 1                           0                            970     Rio Branco
# 2                           0                            970     Rio Branco
# 3                           4                              0     Acrelândia
# 4                           0                            970     Rio Branco
#
#    AP_MUNPCN_latitude  AP_MUNPCN_longitude  AP_MUNPCN_capital  \
# 0            -9.97499             -67.8243                1.0
# 1            -9.97499             -67.8243                1.0
# 2            -9.97499             -67.8243                1.0
# 3            -9.82581             -66.8972                0.0
# 4            -9.97499             -67.8243                1.0
#
#    AP_MUNPCN_codigo_uf AP_UFMUN_nome  AP_UFMUN_latitude  AP_UFMUN_longitude  \
# 0                 12.0    Rio Branco           -9.97499            -67.8243
# 1                 12.0    Rio Branco           -9.97499            -67.8243
# 2                 12.0    Rio Branco           -9.97499            -67.8243
# 3                 12.0    Rio Branco           -9.97499            -67.8243
# 4                 12.0    Rio Branco           -9.97499            -67.8243
#
#    AP_UFMUN_capital  AP_UFMUN_codigo_uf AP_CEPPCN_BAIRRO  \
# 0                 1                  12           Centro
# 1                 1                  12           Centro
# 2                 1                  12           Centro
# 3                 1                  12              NaN
# 4                 1                  12           Centro
#
#                AP_CEPPCN_COMPLEMENTO
# 0  Avenida Epaminondas Jácome, 2858
# 1  Avenida Epaminondas Jácome, 2858
# 2  Avenida Epaminondas Jácome, 2858
# 3                                NaN
# 4  Avenida Epaminondas Jácome, 2858

# %%
data.groupby('AQ_ESTADI')['AQ_ESTADI'].count()
# Out:
# AQ_ESTADI
# 0.0    70384
# 1.0    31607
# 2.0    55267
# 3.0    73850
# 4.0    72823
# Name: AQ_ESTADI, dtype: int64
