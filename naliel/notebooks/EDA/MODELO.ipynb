# %%
import pandas as pd
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from model import predict_sia
import shap
import utils

pd.set_option('display.max_columns', 500)
# %matplotlib inline
# %load_ext line_profiler

# %% [markdown]
# ### LINFOMA

# %% [markdown]
# #### Radioterapia

# %%
# %time model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Linfomas Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (42,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')
# ...

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt

skplt.metrics.plot_roc_curve(y_test, prob_preds)
plt.show()
# Out:
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:85: DeprecationWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
# %time model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Linfomas Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (38,39,41,42,44,45,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### MAMA

# %% [markdown]
# #### Radioterapia

# %%
model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Mama Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Reading csv...
# b'Skipping line 100354: expected 74 fields, saw 87\n'
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (33,38,40,42,44,45,49,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Mama Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Reading csv...
# b'Skipping line 100354: expected 74 fields, saw 87\n'
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (33,38,40,42,44,45,49,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### PROSTATA

# %% [markdown]
# #### Radioterapia

# %%
model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Prostata Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Reading csv...
# b'Skipping line 40771: expected 74 fields, saw 113\n'
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (38,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
# %time model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Prostata Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (22,29,30,32,33,35,37,38,39,41,42,44,46,49,50,51,52,54,56,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### Pulmão

# %% [markdown]
# #### Radioterapia

# %%
# %time model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Pulmão Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Reading csv...
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# training model...
# ROC_AUC_SCORE: 60.54%
# ...

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt

skplt.metrics.plot_roc_curve(y_test, prob_preds)
plt.show()
# Out:
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:85: DeprecationWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
# %time model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Pulmão Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (21,38,39,41,42,44) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')
# ...

# %%
import scikitplot as skplt
import matplotlib.pyplot as plt

skplt.metrics.plot_roc_curve(y_test, prob_preds)
plt.show()
# Out:
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/sklearn/utils/deprecation.py:85: DeprecationWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# ### COLO

# %% [markdown]
# #### Radioterapia

# %%
model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Colon e reto Radioterapia SIA-SUS.csv', method='radioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (42) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")

# %% [markdown]
# #### Quimioterapia

# %%
# %time model, X, X_with_cep, y_test, prob_preds, best_preds = predict_sia('../data/Colon e reto Quimioterapia SIA-SUS.csv', method='quimioterapia')
# Out:
# Reading csv...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/model.py:67: DtypeWarning: Columns (38,39,41,42,44,46,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   X, X_with_cep, y, y_test, d_train, d_test = get_train_and_test_data(path, method)
# Transforming csv to train...
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=4, skipfooter=10, encoding='latin1')
# /Users/helderrezende/Documents/naliel_bcggamma/naliel/datalayer.py:60: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(path, sep=';', skiprows=rowsskip, skipfooter=footerrows, encoding='latin1')
# ...

# %%
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X)

shap.summary_plot(shap_values, X, plot_type="bar")
