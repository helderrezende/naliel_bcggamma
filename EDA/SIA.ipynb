# %%
import pandas as pd
import sys
import os

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from datalayer import read_csv_sia


# %matplotlib inline

# %% [markdown]
# ### Reading data...

# %%
data = read_csv_sia('../data/Linfomas Radioterapia SIA-SUS.csv')
# Out:
# /Users/helderrezende/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3248: DtypeWarning: Columns (42,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
data.head()
# Out:
#    AP_MVM AP_CONDIC  AP_GESTAO  AP_CODUNI     AP_AUTORIZ  AP_CMP  AP_PRIPAL  \
# 0  201401        EP     120000    2001586  1214200029119  201401  304010090
# 1  201402        EP     120000    2001586  1214200045201  201402  304010090
# 2  201402        EP     120000    2001586  1214200029119  201402  304010090
# 3  201403        EP     120000    2001586  1214200045201  201403  304010090
# 4  201405        EP     120000    2001586  1214200084944  201405  304010090
#
#    AP_VL_AP  AP_UFMUN  AP_TPUPS  ...  AR_FINALI AR_CIDTR1  AR_CIDTR2  \
# 0       614    120040         5  ...          2      C811        NaN
# 1      2098    120040         5  ...          1       C61        NaN
# 2       630    120040         5  ...          2      C811        NaN
# 3      2550    120040         5  ...          1       C61        NaN
# 4       810    120040         5  ...          2      C810        NaN
#
#    AR_NUMC1   AR_INIAR1  AR_INIAR2   AR_FIMAR1 AR_FIMAR2  AR_NUMC2  AR_NUMC3
# 0      34.0  20130127.0        NaN  20140228.0       NaN       NaN       NaN
# 1     144.0  20140212.0        NaN  20140430.0       NaN       NaN       NaN
# 2      34.0  20130127.0        NaN  20140228.0       NaN       NaN       NaN
# 3     144.0  20140212.0        NaN  20140331.0       NaN       NaN       NaN
# 4      60.0  20140318.0        NaN  20140531.0       NaN       NaN       NaN
#
# [5 rows x 63 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19920 entries, 0 to 19919
# Data columns (total 63 columns):
# AP_MVM        19920 non-null int64
# AP_CONDIC     19920 non-null object
# AP_GESTAO     19920 non-null int64
# AP_CODUNI     19920 non-null int64
# AP_AUTORIZ    19920 non-null int64
# AP_CMP        19920 non-null int64
# AP_PRIPAL     19920 non-null int64
# AP_VL_AP      19920 non-null int64
# AP_UFMUN      19920 non-null int64
# AP_TPUPS      19920 non-null int64
# AP_TIPPRE     19920 non-null int64
# AP_MN_IND     19920 non-null object
# AP_CNPJCPF    19920 non-null int64
# AP_CNPJMNT    12755 non-null float64
# AP_CNSPCN     19920 non-null object
# AP_COIDADE    19920 non-null int64
# AP_NUIDADE    19920 non-null int64
# AP_SEXO       19920 non-null object
# AP_RACACOR    19920 non-null int64
# AP_MUNPCN     19920 non-null int64
# AP_UFNACIO    19920 non-null int64
# AP_CEPPCN     19920 non-null int64
# AP_UFDIF      19920 non-null int64
# AP_DTINIC     19920 non-null int64
# AP_DTFIM      19920 non-null int64
# AP_TPAPAC     19920 non-null int64
# AP_MOTSAI     19920 non-null int64
# AP_OBITO      19920 non-null int64
# AP_ENCERR     19920 non-null int64
# AP_PERMAN     19920 non-null int64
# AP_ALTA       19920 non-null int64
# AP_TRANSF     19920 non-null int64
# AP_DTOCOR     8731 non-null float64
# AP_CODEMI     19920 non-null object
# AP_CATEND     19920 non-null int64
# AP_APACANT    17831 non-null float64
# AP_UNISOL     19818 non-null float64
# AP_DTSOLIC    18870 non-null float64
# AP_DTAUT      18450 non-null float64
# AP_CIDCAS     19920 non-null object
# AP_CIDPRI     19920 non-null object
# AP_CIDSEC     19920 non-null object
# AR_CID10      10676 non-null object
# AR_LINFIN     19920 non-null object
# AR_ESTADI     19782 non-null float64
# AR_GRAHIS     19918 non-null object
# AR_DTIDEN     19920 non-null object
# AR_TRANTE     14260 non-null object
# AR_CIDINI1    5620 non-null object
# AR_DTINI1     6792 non-null float64
# AR_DTINI2     2063 non-null float64
# AR_CONTTR     19920 non-null object
# AR_DTINTR     19920 non-null int64
# AR_FINALI     19920 non-null int64
# AR_CIDTR1     18523 non-null object
# AR_CIDTR2     3199 non-null object
# AR_NUMC1      18860 non-null float64
# AR_INIAR1     18582 non-null float64
# AR_INIAR2     3375 non-null float64
# AR_FIMAR1     18570 non-null float64
# AR_FIMAR2     3375 non-null float64
# AR_NUMC2      9822 non-null float64
# AR_NUMC3      8709 non-null float64
# dtypes: float64(16), int64(30), object(17)
# memory usage: 9.6+ MB

# %% [markdown]
# ### Analyzing Numerical Variables

# %%
numerical = data._get_numeric_data().columns
data[numerical].hist(bins=15, figsize=(30, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11b805080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1daf60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c896438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x103af09e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114915f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114972470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149a3a20>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1149d6fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1149e3080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114c84b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x114d10160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11822e710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11825ecc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1187252b0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118756860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118788e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a5e400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118a8f9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118ac3f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b00550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x118b84b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x118bc20f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b2be6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b2f0c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b32f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b35e7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117e89940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11b780ef0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11b7bd4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc1ea90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc5b080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bc8e630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11bcbebe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c8211d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c851780>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11cfc3d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cfff320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d0328d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d063e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d0a2470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d0d2a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d105fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11d1425c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d174b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d1b2160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d225710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d254cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d2d52b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11d303860>]],
#       dtype=object)
